# %% [markdown]
# <a href="https://colab.research.google.com/github/GrmRy/Skripsi/blob/main/tes_skripsi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np 
import matplotlib as plt
import tensorflow as tf

# %%
url="https://raw.githubusercontent.com/GrmRy/Skripsi/main/DigitalForecast-JawaTengah.csv"
df=pd.read_csv(url)
df.head()
# Out:
#   name/0/_xml:lang name/0/__text name/1/_xml:lang      name/1/__text  \
# 0            en_US  Banjarnegara            id_ID  Kab. Banjarnegara
# 1            en_US        Batang            id_ID        Kab. Batang
# 2            en_US         Blora            id_ID         Kab. Blora
# 3            en_US      Boyolali            id_ID      Kab. Boyolali
# 4            en_US        Brebes            id_ID        Kab. Brebes
#
#   parameter/0/timerange/0/value/0/_unit  \
# 0                                     %
# 1                                     %
# 2                                     %
# 3                                     %
# 4                                     %
#
#    parameter/0/timerange/0/value/0/__text parameter/0/timerange/0/_type  \
# 0                                    80.0                        hourly
# 1                                    75.0                        hourly
# 2                                    75.0                        hourly
# ...
